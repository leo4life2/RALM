# %%
import re

# %%
f = open("data/markdown/olympics_sections.md", "r")
all_text = f.read()

# %%
title_split = re.split(r"## |### ", all_text)

# %%
title_split
# Out:
# ['',
#  '2020 Summer Olympics\n\n',
# ...

# %%
title_split[1].find("\n\n") < len(title_split[1]) - 2
# Out:
# False

# %%
len(title_split[1])
# Out:
# 22

# %%
heading, content, _ = title_split[2].split("\n\n", 2)
heading, content
# Out:
# ('Summary',
# ...
